# %%
import pandas as pd

# %%
#Import EAP Florida Modern Deer Data
deerData = pd.read_csv("EAP_deer_data.xlsx")

#Initial modification of the data frame
#Start at correct row
deerData = deerData.iloc[36:]

#Set the headers
deerData = deerData.rename(columns=deerData.iloc[0])

#Drop additional unnecessary rows
deerData = deerData.drop(deerData.index[0])

#Add ageUnit column and populate it with years
deerData=deerData.assign(ageUnit = "years")
deerData
# Out:
#     36 Compiled Terms [EAP database terms are in square brackets]  \
# 37  37                                                NaN
# 38  38                                                NaN
# 39  39                                                NaN
# 40  40                                                NaN
# 41  41                                                NaN
# 42  42                                                NaN
# 43  43                                                NaN
# 44  44                                                NaN
# 45  45                                                NaN
# 46  46                                                NaN
# 47  47                                                NaN
# 48  48                                                NaN
# 49  49                                                NaN
# 50  50                                                NaN
# 51  51                                                NaN
# 52  52                                                NaN
# 53  53                                                NaN
# 54  54                                                NaN
# 55  55                                                NaN
# 56  56                                                NaN
# 57  57                                                NaN
# 58  58                                                NaN
# 59  59                                                NaN
# 60  60                                                NaN
# 61  61                                                NaN
# 62  62                                                NaN
# 63  63                                                NaN
# 64  64                                                NaN
# 65  65                                                NaN
# 66  66                                                NaN
# 67  67                                                NaN
#
#                            Occurrence ID Other References to this Occurrence  \
# 37                                    --                                  --
# 38                                    --                                  --
# 39                                    --                                  --
# 40                                    --                                  --
# 41                                    --                                  --
# 42                                    --                                  --
# 43                                    --                                  --
# 44  might have UF Mammalogy occurrenceID                        UF Mammalogy
# 45  might have UF Mammalogy occurrenceID                        UF Mammalogy
# 46                                    --                                  --
# 47                                    --                                  --
# 48                                    --                                  --
# 49  might have UF Mammalogy occurrenceID                        UF Mammalogy
# 50  might have UF Mammalogy occurrenceID                        UF Mammalogy
# 51  might have UF Mammalogy occurrenceID                        UF Mammalogy
# 52                                    --                                  --
# 53                                    --                                  --
# 54                                    --                                  --
# 55                                    --                                  --
# 56                                    --                                  --
# 57  might have UF Mammalogy occurrenceID                        UF Mammalogy
# 58                                    --                                  --
# 59                                    --                                  --
# 60                                    --                                  --
# 61                                    --                                  --
# 62                                    --                                  --
# 63  might have UF Mammalogy occurrenceID                        UF Mammalogy
# 64                                    --                                  --
# 65                                    --                                  --
# 66                                    --                                  --
# 67                                    --                        UF Mammalogy
#
#    Taxon [in EA database this is taxon + Species]        Common Name  \
# 37                         Odocoileus virginianus  white tailed deer
# 38                         Odocoileus virginianus  white tailed deer
# 39                         Odocoileus virginianus  white tailed deer
# 40                         Odocoileus virginianus  white tailed deer
# 41                         Odocoileus virginianus  white tailed deer
# 42                         Odocoileus virginianus  white tailed deer
# 43                         Odocoileus virginianus  white tailed deer
# 44                         Odocoileus virginianus  white tailed deer
# 45                         Odocoileus virginianus  white tailed deer
# 46                         Odocoileus virginianus  white tailed deer
# 47                         Odocoileus virginianus  white tailed deer
# 48                         Odocoileus virginianus  white tailed deer
# 49                         Odocoileus virginianus  white tailed deer
# 50                         Odocoileus virginianus  white tailed deer
# 51                         Odocoileus virginianus  white tailed deer
# 52                         Odocoileus virginianus  white tailed deer
# 53                         Odocoileus virginianus  white tailed deer
# 54                         Odocoileus virginianus  white tailed deer
# 55                         Odocoileus virginianus  white tailed deer
# 56                         Odocoileus virginianus  white tailed deer
# 57                         Odocoileus virginianus  white tailed deer
# 58                         Odocoileus virginianus  white tailed deer
# 59                         Odocoileus virginianus  white tailed deer
# 60                         Odocoileus virginianus  white tailed deer
# 61                         Odocoileus virginianus  white tailed deer
# 62                         Odocoileus virginianus  white tailed deer
# 63                         Odocoileus virginianus  white tailed deer
# 64                         Odocoileus virginianus  white tailed deer
# 65                         Odocoileus virginianus  white tailed deer
# 66                         Odocoileus virginianus  white tailed deer
# 67                         Odocoileus virginianus  white tailed deer
#
#    [Kingdom]  [Phylum]   [Class]       [Order]  ...  \
# 37  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 38  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 39  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 40  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 41  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 42  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 43  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 44  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 45  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 46  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 47  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 48  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 49  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 50  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 51  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 52  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 53  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 54  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 55  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 56  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 57  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 58  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 59  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 60  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 61  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 62  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 63  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 64  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 65  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 66  Animalia  Chordata  Mammalia  Artiodactyla  ...
# 67  Animalia  Chordata  Mammalia  Artiodactyla  ...
#
#    Bp, (greatest breadth of the proximal end, von den Driesch 1976), mm  \
# 37                                                 --
# 38                                                 --
# 39                                              51.61
# 40                                                 --
# 41                                                 --
# 42                                                 --
# 43                                              44.99
# 44                                              44.75
# 45                                                 --
# 46                                              54.26
# 47                                              45.84
# 48                                              47.18
# 49                                              52.81
# 50                                              45.07
# 51                                                 --
# 52                                                 --
# 53                                                 --
# 54                                              48.11
# 55                                              43.33
# 56                                                 --
# 57                                                 --
# 58                                              45.06
# 59                                              48.43
# 60                                                 --
# 61                                              45.48
# 62                                               48.3
# 63                                                 --
# 64                                                 --
# 65                                                 --
# 66                                                 --
# 67                                                NaN
#
#    Bd, (greatest breadth of the distal end, von den Driesch 1976), mm  \
# 37                                              31.99
# 38                                              31.57
# 39                                              32.54
# 40                                              30.77
# 41                                                 --
# 42                                              30.62
# 43                                              27.74
# 44                                              28.84
# 45                                                 --
# 46                                              33.65
# 47                                              27.92
# 48                                              30.01
# 49                                              32.31
# 50                                              28.96
# 51                                                 --
# 52                                              29.78
# 53                                                 --
# 54                                              30.43
# 55                                              27.36
# 56                                              28.65
# 57                                                 --
# 58                                              22.87
# 59                                              31.18
# 60                                              30.57
# 61                                              29.72
# 62                                              31.98
# 63                                                 --
# 64                                              30.33
# 65                                                 --
# 66                                              28.37
# 67                                                NaN
#
#    Dd, (greatest depth of the distal end, von den Driesch 1976), mm  \
# 37                                               24.6
# 38                                              23.56
# 39                                              25.66
# 40                                              24.87
# 41                                                 --
# 42                                              23.05
# 43                                              21.54
# 44                                              23.27
# 45                                                 --
# 46                                              27.27
# 47                                              21.84
# 48                                              24.73
# 49                                              25.48
# 50                                              21.43
# 51                                                 --
# 52                                              22.23
# 53                                                 --
# 54                                              24.21
# 55                                              21.68
# 56                                              23.38
# 57                                                 --
# 58                                              22.59
# 59                                              24.49
# 60                                              24.12
# 61                                              22.72
# 62                                               23.8
# 63                                                 --
# 64                                              24.74
# 65                                                 --
# 66                                              22.77
# 67                                                NaN
#
#                          Skeletal Measurement Remarks  \
# 37                             proximal tibia unfused
# 38                             proximal tibia unfused
# 39                                                NaN
# 40                             proximal tibia unfused
# 41                  proximal and distal tibia unfused
# 42                             proximal tibia unfused
# 43                                                NaN
# 44                                                NaN
# 45                  proximal and distal tibia unfused
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                  proximal and distal tibia unfused
# 52                             proximal tibia unfused
# 53                  proximal and distal tibia unfused
# 54                                                NaN
# 55                                                NaN
# 56                             proximal tibia unfused
# 57                  proximal and distal tibia unfused
# 58                                                NaN
# 59                                                NaN
# 60  tibia split centrally so length and diameter m...
# 61                                                NaN
# 62                                                NaN
# 63                  proximal and distal tibia unfused
# 64                             proximal tibia unfused
# 65                  proximal and distal tibia unfused
# 66                             proximal tibia unfused
# 67                                                NaN
#
#              Skeletal Measurements by Skeletal Measurement Date  \
# 37                   Samantha McCrane       2019-10-01 00:00:00
# 38                   Samantha McCrane       2019-10-01 00:00:00
# 39                       Jessica King       2019-10-01 00:00:00
# 40                   Samantha McCrane       2019-10-01 00:00:00
# 41                   Samantha McCrane       2019-10-01 00:00:00
# 42                   Samantha McCrane       2019-10-01 00:00:00
# 43                   Samantha McCrane       2019-10-01 00:00:00
# 44                   Samantha McCrane       2019-10-01 00:00:00
# 45                       Jessica King       2019-10-01 00:00:00
# 46                       Jessica King       2019-10-01 00:00:00
# 47                       Jessica King       2019-10-01 00:00:00
# 48                   Samantha McCrane       2019-10-01 00:00:00
# 49  Jessica King and Samantha McCrane       2019-10-01 00:00:00
# 50                   Samantha McCrane       2019-10-01 00:00:00
# 51                   Samantha McCrane       2019-10-01 00:00:00
# 52  Jessica King and Samantha McCrane       2019-10-01 00:00:00
# 53  Jessica King and Samantha McCrane       2019-10-01 00:00:00
# 54                       Jessica King       2019-10-01 00:00:00
# 55                   Samantha McCrane       2019-10-01 00:00:00
# 56                   Samantha McCrane       2019-10-01 00:00:00
# 57                   Samantha McCrane       2019-10-01 00:00:00
# 58                   Samantha McCrane       2019-10-01 00:00:00
# 59                       Jessica King       2019-10-01 00:00:00
# 60                       Jessica King       2019-10-01 00:00:00
# 61                   Samantha McCrane       2019-10-01 00:00:00
# 62                   Samantha McCrane       2019-10-01 00:00:00
# 63                   Samantha McCrane       2019-10-01 00:00:00
# 64                       Jessica King       2019-10-01 00:00:00
# 65                   Samantha McCrane       2019-10-01 00:00:00
# 66                       Jessica King       2019-10-01 00:00:00
# 67                                NaN                       NaN
#
#                           Skeletal Measurement Method  \
# 37  Tibia GL and LI taken with generic (Marathon-s...
# 38  Tibia GL and LI taken with generic (Marathon-s...
# 39  Tibia GL and LI taken with generic (Marathon-s...
# 40  Tibia GL and LI taken with generic (Marathon-s...
# 41  Tibia GL and LI taken with generic (Marathon-s...
# 42  Tibia GL and LI taken with generic (Marathon-s...
# 43  Tibia GL and LI taken with generic (Marathon-s...
# 44  Tibia GL and LI taken with generic (Marathon-s...
# 45  Tibia GL and LI taken with generic (Marathon-s...
# 46  Tibia GL and LI taken with generic (Marathon-s...
# 47  Tibia GL and LI taken with generic (Marathon-s...
# 48  Tibia GL and LI taken with generic (Marathon-s...
# 49  Tibia GL and LI taken with generic (Marathon-s...
# 50  Tibia GL and LI taken with generic (Marathon-s...
# 51  Tibia GL and LI taken with generic (Marathon-s...
# 52  Tibia GL and LI taken with generic (Marathon-s...
# 53  Tibia GL and LI taken with generic (Marathon-s...
# 54  Tibia GL and LI taken with generic (Marathon-s...
# 55  Tibia GL and LI taken with generic (Marathon-s...
# 56  Tibia GL and LI taken with generic (Marathon-s...
# 57  Tibia GL and LI taken with generic (Marathon-s...
# 58  Tibia GL and LI taken with generic (Marathon-s...
# 59  Tibia GL and LI taken with generic (Marathon-s...
# 60  Tibia GL and LI taken with generic (Marathon-s...
# 61  Tibia GL and LI taken with generic (Marathon-s...
# 62  Tibia GL and LI taken with generic (Marathon-s...
# 63  Tibia GL and LI taken with generic (Marathon-s...
# 64  Tibia GL and LI taken with generic (Marathon-s...
# 65  Tibia GL and LI taken with generic (Marathon-s...
# 66  Tibia GL and LI taken with generic (Marathon-s...
# 67                                                NaN
#
#                                      Caliper Accuracy  NaN ageUnit
# 37  unknown for fresh carcass field weights and me...  NaN   years
# 38  unknown for fresh carcass field weights and me...  NaN   years
# 39  unknown for fresh carcass field weights and me...  NaN   years
# 40  unknown for fresh carcass field weights and me...  NaN   years
# 41  unknown for fresh carcass field weights and me...  NaN   years
# 42  unknown for fresh carcass field weights and me...  NaN   years
# 43  unknown for fresh carcass field weights and me...  NaN   years
# 44  unknown for fresh carcass field weights and me...  NaN   years
# 45  unknown for fresh carcass field weights and me...  NaN   years
# 46  unknown for fresh carcass field weights and me...  NaN   years
# 47  unknown for fresh carcass field weights and me...  NaN   years
# 48  unknown for fresh carcass field weights and me...  NaN   years
# 49  unknown for fresh carcass field weights and me...  NaN   years
# 50  unknown for fresh carcass field weights and me...  NaN   years
# 51  unknown for fresh carcass field weights and me...  NaN   years
# 52  unknown for fresh carcass field weights and me...  NaN   years
# 53  unknown for fresh carcass field weights and me...  NaN   years
# 54  unknown for fresh carcass field weights and me...  NaN   years
# 55  unknown for fresh carcass field weights and me...  NaN   years
# 56  unknown for fresh carcass field weights and me...  NaN   years
# 57  unknown for fresh carcass field weights and me...  NaN   years
# 58  unknown for fresh carcass field weights and me...  NaN   years
# 59  unknown for fresh carcass field weights and me...  NaN   years
# 60  unknown for fresh carcass field weights and me...  NaN   years
# 61  unknown for fresh carcass field weights and me...  NaN   years
# 62  unknown for fresh carcass field weights and me...  NaN   years
# 63  unknown for fresh carcass field weights and me...  NaN   years
# 64  unknown for fresh carcass field weights and me...  NaN   years
# 65  unknown for fresh carcass field weights and me...  NaN   years
# 66  unknown for fresh carcass field weights and me...  NaN   years
# 67                                                NaN  NaN   years
#
# [31 rows x 120 columns]

# %%
#Rearrange columns so that template columns are first, followed by measurement values

#Create column list
cols = deerData.columns.tolist()

#Specify desired columns
cols = ['Other References to this Occurrence',
        'Taxon [in EA database this is taxon + Species]',
        'EA Cat number [in EA database, this is catalog+catalog extension]',
        '[Collector Number]',
        'Organism ID',
        '[Sex]',
        'ageUnit',
        '[Age] Value in Years [in EA database, all age info goes in one category = Age]',
        '[Age] Life Stage',
        '[Country]',
        'State [also in EA database as Country/State]',
        'Locality [in EAP database as City/Modifier]',
        'Verbatim Locality',
        'Latitude',
        'Longitude',
        'Coordinate Uncertainty in Meters',
        'Minimum Elevation in Meters',
        'Maximum Elevation in Meters',
        'Collection Date [EAP database has only one date category, randomly used for whatever]',
        'Material Sample ID',
        'Sampling Protocol',
        'Total Fresh Weight (g)',
        'TL (mm) [Total Length]',
        'HF (mm) [Hind Foot Length]',
        'En (mm) [Ear Notch = Ear Length]',
        'Carcass Measurement Methods',
        'Reproductive Condition',
        'Event Remarks',
        'Carcass Measurement Determined By',
        'Carcass Measurement Accuracy [for all carcass data]',
        'Skeletal Element Name (1)',
        'Side Measured 1'
       ]

#Subset dataframe
deerData = deerData[cols]

# %%
#Matching template and column terms

#Renaming columns 
deerData = deerData.rename(columns = {'Other References to this Occurrence':'references',
                                     'Taxon [in EA database this is taxon + Species]': 'scientificName',
                                     'EA Cat number [in EA database, this is catalog+catalog extension]':'catalogNumber',
                                     '[Collector Number]':'collectionCode',
                                     'Organism ID': 'organismID',
                                     '[Sex]':'sex',
                                     '[Age] Value in Years [in EA database, all age info goes in one category = Age]': 'ageValue',
                                     '[Age] Life Stage': 'lifeStage',
                                     '[Country]': 'country',
                                     'State [also in EA database as Country/State]':'stateProvince',
                                     'Locality [in EAP database as City/Modifier]': 'locality',
                                     'Verbatim Locality':'verbatimLocality',
                                     'Latitude': 'decimalLatitude',
                                     'Longitude':'decimalLongitude',
                                     'Coordinate Uncertainty in Meters':'coordinateUncertaintyInMeters',
                                     'Minimum Elevation in Meters':'minimumElevationInMeters',
                                     'Maximum Elevation in Meters':'maximumElevationInMeters',
                                     'Collection Date [EAP database has only one date category, randomly used for whatever]':'verbatimEventDate',
                                     'Material Sample ID':'materialSampleID',
                                     'Sampling Protocol':'samplingProtocol',
                                     'Carcass Measurement Methods':'measurementMethod',
                                     'Reproductive Condition':'reproductiveCondition',
                                     'Event Remarks':'eventRemarks',
                                     'Carcass Measurement Determined By': 'measurementDeterminedBy',
                                     'Carcass Measurement Accuracy [for all carcass data]':'measurementAccuracy'})

# %%
#Matching trait and ontology terms

#Renaming columns
deerData = deerData.rename(columns={'Total Fresh Weight (g)': 'body mass',
                                    'TL (mm) [Total Length]': 'full body length',
                                    'HF (mm) [Hind Foot Length]':'hind foot length',
                                    'En (mm) [Ear Notch = Ear Length]':'ear length',
                                    'Height (mm) [define?]': 'height'})

# %%
#create long version so that each trait has its own row

#creating long version, first specifiying keep variables, then naming variable and value
longVers=pd.melt(deerData, 
                id_vars=['references',
                         'scientificName',
                         'catalogNumber',
                         'collectionCode',
                         'organismID',
                         'sex',
                         'ageUnit',
                         'ageValue',
                         'lifeStage',
                         'country',
                         'stateProvince',
                         'locality',
                         'verbatimLocality',
                         'decimalLatitude',
                         'decimalLongitude',
                         'coordinateUncertaintyInMeters',
                         'minimumElevationInMeters',
                         'maximumElevationInMeters',
                         'verbatimEventDate',
                         'materialSampleID',
                         'samplingProtocol',
                         'measurementMethod',
                         'reproductiveCondition',
                         'eventRemarks',
                         'measurementAccuracy',
                         'measurementDeterminedBy'], 
                var_name = 'trait', 
                value_name = 'measurement')

                                
#Writing long data csv file
longVers.to_csv('DeerData_Data_Long.csv')
