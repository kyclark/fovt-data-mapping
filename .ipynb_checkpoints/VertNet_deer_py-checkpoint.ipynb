# %%
import pandas as pd

# %%
#Import Deer VertNet Data
deer = pd.read_csv("https://de.cyverse.org/dl/d/126821C9-D23A-4B22-9B3F-25F19311066E/ODOVIRGCLEAN.csv")

# %%
#Rearrange columns so that template columns are first, followed by measurement values

#Create column list
cols = deer.columns.tolist()

#Specify desired columns
cols = ['catalognumber',
        'collectioncode',
        'decimallatitude',
        'decimallongitude',
        'eventdate',
        'institutioncode',
        'lifestage',
        'locality',
        'sex',
        'scientificname',
        '1st_body_mass',
        '1st_ear_length',
        '1st_hind_foot_length',
        '1st_tail_length',
        '1st_total_length']

#Subset dataframe
deer=deer[cols]

# %%
#Matching template and column terms

#Renaming columns 
deer = deer.rename(columns={'catalognumber':'catalogNumber', 
                            'collectioncode':'collectionCode',
                            'decimallatitude':'decimalLatitude',
                            'decimallongitude':'decimalLongitude',
                            'eventdate':'verbatimEventDate',
                            'institutioncode' :'institutionCode',
                            'lifestage':'lifeStage',
                            'locality':'verbatimLocality',
                            'scientificname':'scientificName'})

# %%
#Matching trait and ontology terms

#Renaming columns
deer = deer.rename(columns={'1st_body_mass':'body mass',
                            '1st_ear_length': 'ear length',
                            '1st_hind_foot_length':'hind foot length',
                            '1st_tail_length':'tail length',
                            '1st_total_length':'full body length'})
deer
# Out:
#       catalogNumber    collectionCode  decimalLatitude  decimalLongitude  \
# 0             18192           Mammals        17.765560        -64.881668
# 1         UAZ 24592           Mammals        31.392203       -110.702582
# 2             18217           Mammals        18.000000        -64.666672
# 3             32127  Mammal specimens        46.247500       -123.412500
# 4             50139           Mammals              NaN               NaN
# ...             ...               ...              ...               ...
# 16899           NaN               NaN              NaN               NaN
# 16900           NaN               NaN              NaN               NaN
# 16901           NaN               NaN              NaN               NaN
# 16902           NaN               NaN              NaN               NaN
# 16903           NaN               NaN              NaN               NaN
#
#       verbatimEventDate institutionCode lifeStage  \
# 0                8/3/72             TTU       NaN
# 1              11/20/81             UAZ       NaN
# 2                5/5/72             TTU       NaN
# 3                  1979            UWBM       NaN
# 4                  2009            OMNH  Juvenile
# ...                 ...             ...       ...
# 16899               NaN             NaN       NaN
# 16900               NaN             NaN       NaN
# 16901               NaN             NaN       NaN
# 16902               NaN             NaN       NaN
# 16903               NaN             NaN       NaN
#
#                                         verbatimLocality     sex  \
# 0                                       CALIDONIA ESTATE    male
# 1      T23S, R16E, ~1 mi. NW Washington Camp on Duque...  female
# 2                                                    NaN  female
# 3                     Columbian White-tailed Deer Refuge    male
# 4                                                    NaN  female
# ...                                                  ...     ...
# 16899                                                NaN     NaN
# 16900                                                NaN     NaN
# 16901                                                NaN     NaN
# 16902                                                NaN     NaN
# 16903                                                NaN     NaN
#
#                scientificName  body mass  ear length  hind foot length  \
# 0      Odocoileus virginianus     9979.0       102.0             275.0
# 1      Odocoileus virginianus     8500.0       120.0             225.0
# 2      Odocoileus virginianus     9979.0       102.0             279.0
# 3      Odocoileus virginianus     5100.0        90.0             300.0
# 4      Odocoileus virginianus     5880.0       100.0             285.0
# ...                       ...        ...         ...               ...
# 16899                     NaN        NaN         NaN               NaN
# 16900                     NaN        NaN         NaN               NaN
# 16901                     NaN        NaN         NaN               NaN
# 16902                     NaN        NaN         NaN               NaN
# 16903                     NaN        NaN         NaN               NaN
#
#        tail length  full body length
# 0            102.0             813.0
# 1            147.0             835.0
# 2            102.0             838.0
# 3            140.0             850.0
# 4            150.0             858.0
# ...            ...               ...
# 16899          NaN               NaN
# 16900          NaN               NaN
# 16901          NaN               NaN
# 16902          NaN               NaN
# 16903          NaN               NaN
#
# [16904 rows x 15 columns]

# %%
#create long version so that each trait has its own row

#creating long version, first specifiying keep variables, then naming variable and value
pd.melt(deer, 
        id_vars=['catalogNumber', 
                'collectionCode',
                'decimalLatitude',
                'decimalLongitude', 
                'verbatimEventDate', 
                'institutionCode',
                'lifeStage',
                'verbatimLocality',
                'sex',
                'scientificName'], 
        var_name = 'trait', 
        value_name = 'measurement')
# Out:
#       catalogNumber    collectionCode  decimalLatitude  decimalLongitude  \
# 0             18192           Mammals        17.765560        -64.881668
# 1         UAZ 24592           Mammals        31.392203       -110.702582
# 2             18217           Mammals        18.000000        -64.666672
# 3             32127  Mammal specimens        46.247500       -123.412500
# 4             50139           Mammals              NaN               NaN
# ...             ...               ...              ...               ...
# 84515           NaN               NaN              NaN               NaN
# 84516           NaN               NaN              NaN               NaN
# 84517           NaN               NaN              NaN               NaN
# 84518           NaN               NaN              NaN               NaN
# 84519           NaN               NaN              NaN               NaN
#
#       verbatimEventDate institutionCode lifeStage  \
# 0                8/3/72             TTU       NaN
# 1              11/20/81             UAZ       NaN
# 2                5/5/72             TTU       NaN
# 3                  1979            UWBM       NaN
# 4                  2009            OMNH  Juvenile
# ...                 ...             ...       ...
# 84515               NaN             NaN       NaN
# 84516               NaN             NaN       NaN
# 84517               NaN             NaN       NaN
# 84518               NaN             NaN       NaN
# 84519               NaN             NaN       NaN
#
#                                         verbatimLocality     sex  \
# 0                                       CALIDONIA ESTATE    male
# 1      T23S, R16E, ~1 mi. NW Washington Camp on Duque...  female
# 2                                                    NaN  female
# 3                     Columbian White-tailed Deer Refuge    male
# 4                                                    NaN  female
# ...                                                  ...     ...
# 84515                                                NaN     NaN
# 84516                                                NaN     NaN
# 84517                                                NaN     NaN
# 84518                                                NaN     NaN
# 84519                                                NaN     NaN
#
#                scientificName             trait  measurement
# 0      Odocoileus virginianus         body mass       9979.0
# 1      Odocoileus virginianus         body mass       8500.0
# 2      Odocoileus virginianus         body mass       9979.0
# 3      Odocoileus virginianus         body mass       5100.0
# 4      Odocoileus virginianus         body mass       5880.0
# ...                       ...               ...          ...
# 84515                     NaN  full body length          NaN
# 84516                     NaN  full body length          NaN
# 84517                     NaN  full body length          NaN
# 84518                     NaN  full body length          NaN
# 84519                     NaN  full body length          NaN
#
# [84520 rows x 12 columns]
