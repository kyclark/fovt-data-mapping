# %% [markdown]
# # To Code
#
# ## template mapping files are in the git repository
# ## original data in _CyVerse Discovery Environment_
# ### data file is: "J.Biogeo.2008.AllData.Final.csv"
#
# ### _catalogNumber_
# - in Specimen.Number column (new catalogNumber)
# - separate out institutionCode from Specimen.Number
# - create new column titled institutionCode
#
# ### _measurementUnit_
# - either in "g" or "mm"
#
# ### _otherCatalogNumbers_
# - concatenated list of:
#     - Proxy.Specimen.Number
#     - Annual.Specimen.Number
#     - YOC.Specimen.Number
#
# ### _materialSampleID_
# - create materialSampleID and assign it a UUID value for each row (before long version)
#
# ### _diagnosticID
# - create diagnosticID and name
#
# ### _eventID
# - create eventID and assign it to materialSampleID values
#
# ### _basisOfRecord_
# - required in GEOME
# - create basisOfRecord column and assign "FossilSpecimen"
#
# ### _locality_
# - required in GEOME
# - create locality column and assign "Unknown"
#
# ### _sampleProtocol_
# - required in GEOME
# - create sampleProtocol column and assign "Unknown"
#
# ### _yearCollected_
# - required in GEOME
# - create yearCollected column and assign "Unknown"
#
# ### _measurementMethod_
# - required in GEOME
# - create measurementMethod column and assign "Unknown"
#
# ### _unused columns_
# - datum (units for latitude)
#
# ### _elevationInMeters_
# - in _elevation.ft_
# - convert ot meters

# %%
import pandas as pd
import numpy as np
import uuid
import re

# %%
#Import Biogeo Data Locally
biogeo = pd.read_csv("../Original Data/biogeo.csv")

# %%
#Preliminary data cleaning

#Convert elevation.ft values from feet to meters
#1 foot is exactly 0.3048 meters
biogeo['elevation.ft']=biogeo['elevation.ft'].multiply(0.3048)
#it's not being renamed here because it is renamed later in the script

# %%
#Preliminary data cleaning

#Creating a new column called institutionCode and moving from Specimen.Number to institutionCode.  
biogeo=biogeo.assign(institutionCode = "")
for ind in biogeo.index:
    x=biogeo['Specimen.Number'][ind]
    y=str(x)
    z=str(y).split()
    biogeo['institutionCode'][ind]=z[0]
    y=re.sub(z[0],'',y)
    biogeo['Specimen.Number'][ind]=y
# Out:
# /Users/neeka/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/neeka/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
#Add required GEOME columms
biogeo=biogeo.assign(basisOfRecord="PreservedSpecimen")
biogeo=biogeo.assign(scientificName="Not Collected")
biogeo=biogeo.assign(country="Unknown")
biogeo=biogeo.assign(locality="Not Collected")
biogeo=biogeo.assign(yearCollected="Unknown")
biogeo=biogeo.assign(samplingProtocol="Not Collected")
biogeo=biogeo.assign(measurementMethod="Unknown")

# %%
#Add measurementUnit column 
biogeo=biogeo.assign(measurementUnit = "")

# %%
#Add otherCatalogNumbers
biogeo=biogeo.assign(otherCatalogNumbers = biogeo['Proxy.Specimen.Number'].fillna('')+biogeo['Annual.Specimen.Number'].fillna('')+biogeo['Annual.Specimen.Number'].fillna('') )

# %%
#Rearrange columns so that template columns are first, followed by measurement values

#Create column list
cols = biogeo.columns.tolist()

#Specify desired columns
cols = ['Specimen.Number',
        'institutionCode',
        'otherCatalogNumbers',
        'dec.lat',
        'dec.long',  
        'max.error',
        'elevation.ft',
        'hind.foot.length.mm',
        'tail.length.mm',
        'total.length.mm',
        'body.mass.g',
        'basisOfRecord',
        'scientificName',
        'country',
        'locality',
        'yearCollected',
        'samplingProtocol',
        'measurementMethod',
        'measurementUnit']

#Subset dataframe
biogeo = biogeo[cols]

# %%
#Matching template and column terms

#Renaming columns 
biogeo = biogeo.rename(columns = {'Specimen.Number':'catalogNumber', 
                                  'dec.lat':'decimalLatitude', 
                                  'dec.long':'decimalLongitude',  
                                  'max.error':'coordinateUncertaintyInMeters', 
                                  'elevation.ft':'pointElevationInMeters'})

# %%
#Matching trait and ontology terms

#Renaming columns
biogeo = biogeo.rename(columns={'hind.foot.length.mm':'pes length',
                                'tail.length.mm': 'tail length',
                                'total.length.mm':'body length',
                                'body.mass.g':'body mass'})

# %%
#create materialSampleID which is a UUID for each measurement
#create eventID and populate it with materialSampleID

biogeo=biogeo.assign(materialSampleID = '')
biogeo['materialSampleID'] = [uuid.uuid4() for _ in range(len(biogeo.index))]

for ind in biogeo.index:
    x=biogeo['materialSampleID'][ind]
    y=str(x)
    z=y.replace("-", '_')
    
    biogeo['materialSampleID'][ind] = z

biogeo=biogeo.assign(eventID = biogeo["materialSampleID"])
# Out:
# /Users/neeka/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
#create long version so that each trait has its own row

#creating long version, first specifiying keep variables, then naming variable and value
longVers=pd.melt(biogeo, 
                id_vars=['catalogNumber',
                         'institutionCode',
                         'otherCatalogNumbers',
                         'decimalLatitude',
                         'decimalLongitude',  
                         'coordinateUncertaintyInMeters',
                         'pointElevationInMeters',
                         'materialSampleID',
                         'eventID',
                         'basisOfRecord',
                         'scientificName',
                         'country',
                         'locality',
                         'yearCollected',
                         'samplingProtocol',
                         'measurementMethod',
                         'measurementUnit'], 
                          var_name = 'measurementType', 
                          value_name = 'measurementValue')

#Populating measurementUnit column with appropriate measurement units in long version
for ind in longVers.index:
    if longVers['measurementType'][ind] == "body mass":
        longVers['measurementUnit'][ind]="g"
    else:
        longVers['measurementUnit'][ind]="mm"
# Out:
# /Users/neeka/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/neeka/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Create diagnosticID which is a unique number for each measurement
longVers=longVers.assign(diagnosticID = '')
longVers['diagnosticID'] = np.arange(len(longVers))

# %%
#If measurement value equals N/a, delete entire row
longVers = longVers.dropna(subset=['measurementValue'])

#Drop first row of data, it contains no measurementValue but is still retained
longVers = longVers.drop(longVers.index[0])

# %%
#round coordinateUncertaintyInMeters column to integer value

for ind in longVers.index:
    x=round(longVers["coordinateUncertaintyInMeters"][ind])
    #y=str(x)
    y=int(x)
   # print (y)
    longVers["coordinateUncertaintyInMeters"][ind]=y
    
longVers
# Out:
# /Users/neeka/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      catalogNumber institutionCode             otherCatalogNumbers  \
# 1           100740             MVZ                      MVZ 100740
# 2           101240             MVZ            MVZ 101240MVZ 101240
# 3           101332             MVZ            MVZ 101332MVZ 101332
# 4           101333             MVZ  MVZ 101333MVZ 101333MVZ 101333
# 5           101334             MVZ                      MVZ 101334
# ...            ...             ...                             ...
# 1127         99914             MVZ                       MVZ 99914
# 1128         99915             MVZ                       MVZ 99915
# 1129         99916             MVZ                       MVZ 99916
# 1130         99917             MVZ                       MVZ 99917
# 1131         99918             MVZ                       MVZ 99918
#
#       decimalLatitude  decimalLongitude  coordinateUncertaintyInMeters  \
# 1           35.328304       -119.845250                            4.0
# 2           37.850522       -122.536923                            2.0
# 3           38.107071       -122.841182                            1.0
# 4           38.119278       -122.821322                            2.0
# 5           38.119278       -122.821322                            2.0
# ...               ...               ...                            ...
# 1127        33.911517       -116.796437                            0.0
# 1128        33.911517       -116.796437                            0.0
# 1129        33.911517       -116.796437                            0.0
# 1130        33.911517       -116.796437                            0.0
# 1131        33.911517       -116.796437                            0.0
#
#       pointElevationInMeters                      materialSampleID  \
# 1                     822.96  47102270_2189_4f2d_9c1a_cef2d3e24c74
# 2                        NaN  a49d1668_f13b_4dbc_bd95_6847b43b2c4e
# 3                        NaN  63c69d7b_e154_416f_ac53_8cd8ad0dbabc
# 4                      45.72  fae1c5fe_fda0_4893_8832_2eec8bc49bfe
# 5                      45.72  4b6b2d94_b1c3_4229_8865_4d999f5dcb8b
# ...                      ...                                   ...
# 1127                  548.64  146084bc_73dc_4e7e_bed6_fead4bf235d4
# 1128                  548.64  1082164e_ec06_43a5_936f_225433860888
# 1129                  548.64  7d605c4b_13b4_450a_a5ce_a6ffda81c708
# 1130                  548.64  97e3b201_e145_40fe_8104_ee571c9ffad9
# 1131                  548.64  66444692_4262_4b15_aab8_d87c99b3e217
#
#                                    eventID      basisOfRecord scientificName  \
# 1     47102270_2189_4f2d_9c1a_cef2d3e24c74  PreservedSpecimen  Not Collected
# 2     a49d1668_f13b_4dbc_bd95_6847b43b2c4e  PreservedSpecimen  Not Collected
# 3     63c69d7b_e154_416f_ac53_8cd8ad0dbabc  PreservedSpecimen  Not Collected
# 4     fae1c5fe_fda0_4893_8832_2eec8bc49bfe  PreservedSpecimen  Not Collected
# 5     4b6b2d94_b1c3_4229_8865_4d999f5dcb8b  PreservedSpecimen  Not Collected
# ...                                    ...                ...            ...
# 1127  146084bc_73dc_4e7e_bed6_fead4bf235d4  PreservedSpecimen  Not Collected
# 1128  1082164e_ec06_43a5_936f_225433860888  PreservedSpecimen  Not Collected
# 1129  7d605c4b_13b4_450a_a5ce_a6ffda81c708  PreservedSpecimen  Not Collected
# 1130  97e3b201_e145_40fe_8104_ee571c9ffad9  PreservedSpecimen  Not Collected
# 1131  66444692_4262_4b15_aab8_d87c99b3e217  PreservedSpecimen  Not Collected
#
#       country       locality yearCollected samplingProtocol measurementMethod  \
# 1     Unknown  Not Collected       Unknown    Not Collected           Unknown
# 2     Unknown  Not Collected       Unknown    Not Collected           Unknown
# 3     Unknown  Not Collected       Unknown    Not Collected           Unknown
# 4     Unknown  Not Collected       Unknown    Not Collected           Unknown
# 5     Unknown  Not Collected       Unknown    Not Collected           Unknown
# ...       ...            ...           ...              ...               ...
# 1127  Unknown  Not Collected       Unknown    Not Collected           Unknown
# 1128  Unknown  Not Collected       Unknown    Not Collected           Unknown
# 1129  Unknown  Not Collected       Unknown    Not Collected           Unknown
# 1130  Unknown  Not Collected       Unknown    Not Collected           Unknown
# 1131  Unknown  Not Collected       Unknown    Not Collected           Unknown
#
#      measurementUnit measurementType measurementValue  diagnosticID
# 1                 mm      pes length               50             1
# 2                 mm      pes length               55             2
# 3                 mm      pes length               52             3
# 4                 mm      pes length               55             4
# 5                 mm      pes length               60             5
# ...              ...             ...              ...           ...
# 1127               g       body mass              725          1127
# 1128               g       body mass              560          1128
# 1129               g       body mass              800          1129
# 1130               g       body mass              760          1130
# 1131               g       body mass              600          1131
#
# [562 rows x 20 columns]

# %%
#Writing long data csv file
longVers.to_csv('../Mapped Data/FuTRES_Spermophilus.beecheyi_Blois_NorthAmerica_Modern.csv', index = False);
